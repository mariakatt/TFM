# %%
# Importar los módulos necesarios
import spacy
import json
import random
import os
import ast
from google.colab import drive
from spacy.training import Example
from spacy.scorer import Scorer
from spacy.tokens import Doc
from spacy import displacy
# !python -m spacy download es_core_news_sm
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from google.colab import drive
import ast
nltk.download('punkt')
import re
# Out:
# Collecting es-core-news-sm==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-3.7.0/es_core_news_sm-3.7.0-py3-none-any.whl (12.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 28.5 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from es-core-news-sm==3.7.0) (3.7.6)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.12.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (4.66.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.8.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (71.0.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2024.8.30)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (13.8.0)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.19.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (7.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.16.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.1.2)
# Installing collected packages: es-core-news-sm
# Successfully installed es-core-news-sm-3.7.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
drive.mount('/content/drive')
tfmPath = '/content/drive/MyDrive/TFM'
trainingFilesPath = tfmPath+'/textos_entrenamiento'
validationFilePath = tfmPath+'/texto_validacion'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
archivo = trainingFilesPath+'/train_forcount.txt'

with open(archivo, 'r', encoding='utf-8') as file:
    content = file.read()

# %%
archivo2 = validationFilePath+'/Val_forcount.txt'

with open(archivo2, 'r', encoding='utf-8') as file:
    content2 = file.read()

# %%
def contar_oraciones_con_palabra(texto_input, palabra):
    print("Estadisticas para la palabra: "+palabra)
    print("----------------------------------------")
    oraciones = sent_tokenize(texto_input)

    count = 0
    total_tokens = 0
    total_types = 0
    longitud_oraciones = []

    for oracion in oraciones:
        palabras = word_tokenize(oracion)
        if palabra in palabras:
            count += 1
            num_tokens = len(palabras)
            num_types = len(set(palabras))
            total_tokens += num_tokens
            total_types += num_types
            longitud_oraciones.append(num_tokens)

    if count > 0:
        media_longitud = total_tokens / count
        media_types = total_types / count
        media_longitud = 0
        media_types = 0

    print(f"Número de oraciones que contienen: {count}")
    print(f"Total de tokens en esas oraciones: {total_tokens}")
    print(f"Total de types (palabras únicas) en esas oraciones: {total_types}")
    print(f"Media de longitud de las oraciones con : {media_longitud}")

    return count, total_tokens, total_types, media_longitud, media_types

# %%
contar_oraciones_con_palabra(content, 'alumnos')
contar_oraciones_con_palabra(content, 'profesores')
contar_oraciones_con_palabra(content, 'investigadores')
contar_oraciones_con_palabra(content, 'habitantes')
contar_oraciones_con_palabra(content, 'camareros')
contar_oraciones_con_palabra(content, 'ingenieros')
contar_oraciones_con_palabra(content, 'clientes')
# Out:
# Estadisticas para la palabra: alumnos
# ----------------------------------------
# Número de oraciones que contienen: 176
# Total de tokens en esas oraciones: 5888
# Total de types (palabras únicas) en esas oraciones: 4861
# Media de longitud de las oraciones con : 33.45454545454545
#
#
# Estadisticas para la palabra: profesores
# ----------------------------------------
# Número de oraciones que contienen: 165
# Total de tokens en esas oraciones: 5863
# Total de types (palabras únicas) en esas oraciones: 4776
# Media de longitud de las oraciones con : 35.53333333333333
#
#
# Estadisticas para la palabra: investigadores
# ----------------------------------------
# Número de oraciones que contienen: 142
# Total de tokens en esas oraciones: 4346
# Total de types (palabras únicas) en esas oraciones: 3683
# Media de longitud de las oraciones con : 30.6056338028169
#
#
# Estadisticas para la palabra: habitantes
# ----------------------------------------
# Número de oraciones que contienen: 150
# Total de tokens en esas oraciones: 5242
# Total de types (palabras únicas) en esas oraciones: 4349
# Media de longitud de las oraciones con : 34.946666666666665
#
#
# Estadisticas para la palabra: camareros
# ----------------------------------------
# Número de oraciones que contienen: 114
# Total de tokens en esas oraciones: 3397
# Total de types (palabras únicas) en esas oraciones: 2816
# Media de longitud de las oraciones con : 29.79824561403509
#
#
# Estadisticas para la palabra: ingenieros
# ----------------------------------------
# Número de oraciones que contienen: 132
# Total de tokens en esas oraciones: 4334
# Total de types (palabras únicas) en esas oraciones: 3559
# Media de longitud de las oraciones con : 32.833333333333336
#
#
# Estadisticas para la palabra: clientes
# ----------------------------------------
# Número de oraciones que contienen: 136
# Total de tokens en esas oraciones: 4531
# Total de types (palabras únicas) en esas oraciones: 3760
# Media de longitud de las oraciones con : 33.31617647058823
# (136, 4531, 3760, 33.31617647058823, 27.647058823529413)

# %%
contar_oraciones_con_palabra(content2, 'alumnos')
contar_oraciones_con_palabra(content2, 'profesores')
contar_oraciones_con_palabra(content2, 'investigadores')
contar_oraciones_con_palabra(content2, 'habitantes')
contar_oraciones_con_palabra(content2, 'camareros')
contar_oraciones_con_palabra(content2, 'ingenieros')
contar_oraciones_con_palabra(content2, 'clientes')
# Out:
# Estadisticas para la palabra: alumnos
# ----------------------------------------
# Número de oraciones que contienen: 28
# Total de tokens en esas oraciones: 811
# Total de types (palabras únicas) en esas oraciones: 711
# Media de longitud de las oraciones con : 28.964285714285715
#
#
# Estadisticas para la palabra: profesores
# ----------------------------------------
# Número de oraciones que contienen: 26
# Total de tokens en esas oraciones: 706
# Total de types (palabras únicas) en esas oraciones: 610
# Media de longitud de las oraciones con : 27.153846153846153
#
#
# Estadisticas para la palabra: investigadores
# ----------------------------------------
# Número de oraciones que contienen: 23
# Total de tokens en esas oraciones: 539
# Total de types (palabras únicas) en esas oraciones: 472
# Media de longitud de las oraciones con : 23.434782608695652
#
#
# Estadisticas para la palabra: habitantes
# ----------------------------------------
# Número de oraciones que contienen: 25
# Total de tokens en esas oraciones: 940
# Total de types (palabras únicas) en esas oraciones: 747
# Media de longitud de las oraciones con : 37.6
#
#
# Estadisticas para la palabra: camareros
# ----------------------------------------
# Número de oraciones que contienen: 20
# Total de tokens en esas oraciones: 530
# Total de types (palabras únicas) en esas oraciones: 432
# Media de longitud de las oraciones con : 26.5
#
#
# Estadisticas para la palabra: ingenieros
# ----------------------------------------
# Número de oraciones que contienen: 24
# Total de tokens en esas oraciones: 724
# Total de types (palabras únicas) en esas oraciones: 583
# Media de longitud de las oraciones con : 30.166666666666668
#
#
# Estadisticas para la palabra: clientes
# ----------------------------------------
# Número de oraciones que contienen: 25
# Total de tokens en esas oraciones: 695
# Total de types (palabras únicas) en esas oraciones: 615
# Media de longitud de las oraciones con : 27.8
# (25, 695, 615, 27.8, 24.6)

# %%
contar_oraciones_con_palabra(content2, 'discapacitado')
contar_oraciones_con_palabra(content2, 'discapacitados')
contar_oraciones_con_palabra(content2, 'discapacitada')
contar_oraciones_con_palabra(content2, 'discapacitadas')
# Out:
# Estadisticas para la palabra: discapacitado
# ----------------------------------------
# Número de oraciones que contienen: 2
# Total de tokens en esas oraciones: 54
# Total de types (palabras únicas) en esas oraciones: 46
# Media de longitud de las oraciones con : 27.0
#
#
# Estadisticas para la palabra: discapacitados
# ----------------------------------------
# Número de oraciones que contienen: 16
# Total de tokens en esas oraciones: 627
# Total de types (palabras únicas) en esas oraciones: 500
# Media de longitud de las oraciones con : 39.1875
#
#
# Estadisticas para la palabra: discapacitada
# ----------------------------------------
# Número de oraciones que contienen: 3
# Total de tokens en esas oraciones: 141
# Total de types (palabras únicas) en esas oraciones: 106
# Media de longitud de las oraciones con : 47.0
#
#
# Estadisticas para la palabra: discapacitadas
# ----------------------------------------
# Número de oraciones que contienen: 3
# Total de tokens en esas oraciones: 132
# Total de types (palabras únicas) en esas oraciones: 100
# Media de longitud de las oraciones con : 44.0
# (3, 132, 100, 44.0, 33.333333333333336)

# %%
contar_oraciones_con_palabra(content, 'discapacitado')
contar_oraciones_con_palabra(content, 'discapacitados')
contar_oraciones_con_palabra(content, 'discapacitada')
contar_oraciones_con_palabra(content, 'discapacitadas')
# Out:
# Estadisticas para la palabra: discapacitado
# ----------------------------------------
# Número de oraciones que contienen: 31
# Total de tokens en esas oraciones: 878
# Total de types (palabras únicas) en esas oraciones: 774
# Media de longitud de las oraciones con : 28.322580645161292
#
#
# Estadisticas para la palabra: discapacitados
# ----------------------------------------
# Número de oraciones que contienen: 98
# Total de tokens en esas oraciones: 3618
# Total de types (palabras únicas) en esas oraciones: 2889
# Media de longitud de las oraciones con : 36.91836734693877
#
#
# Estadisticas para la palabra: discapacitada
# ----------------------------------------
# Número de oraciones que contienen: 7
# Total de tokens en esas oraciones: 192
# Total de types (palabras únicas) en esas oraciones: 170
# Media de longitud de las oraciones con : 27.428571428571427
#
#
# Estadisticas para la palabra: discapacitadas
# ----------------------------------------
# Número de oraciones que contienen: 25
# Total de tokens en esas oraciones: 800
# Total de types (palabras únicas) en esas oraciones: 686
# Media de longitud de las oraciones con : 32.0
# (25, 800, 686, 32.0, 27.44)

# %%
contar_oraciones_con_palabra(content2, 'minusválido')
contar_oraciones_con_palabra(content2, 'minusválidos')
contar_oraciones_con_palabra(content2, 'minusválida')
contar_oraciones_con_palabra(content2, 'minusválidas')
# Out:
# Estadisticas para la palabra: minusválido
# ----------------------------------------
# Número de oraciones que contienen: 9
# Total de tokens en esas oraciones: 342
# Total de types (palabras únicas) en esas oraciones: 289
# Media de longitud de las oraciones con : 38.0
#
#
# Estadisticas para la palabra: minusválidos
# ----------------------------------------
# Número de oraciones que contienen: 18
# Total de tokens en esas oraciones: 599
# Total de types (palabras únicas) en esas oraciones: 495
# Media de longitud de las oraciones con : 33.27777777777778
#
#
# Estadisticas para la palabra: minusválida
# ----------------------------------------
# Número de oraciones que contienen: 3
# Total de tokens en esas oraciones: 78
# Total de types (palabras únicas) en esas oraciones: 66
# Media de longitud de las oraciones con : 26.0
#
#
# Estadisticas para la palabra: minusválidas
# ----------------------------------------
# Número de oraciones que contienen: 0
# Total de tokens en esas oraciones: 0
# Total de types (palabras únicas) en esas oraciones: 0
# Media de longitud de las oraciones con : 0
# (0, 0, 0, 0, 0)

# %%
contar_oraciones_con_palabra(content, 'minusválido')
contar_oraciones_con_palabra(content, 'minusválidos')
contar_oraciones_con_palabra(content, 'minusválida')
contar_oraciones_con_palabra(content, 'minusválidas')
# Out:
# Estadisticas para la palabra: minusválido
# ----------------------------------------
# Número de oraciones que contienen: 27
# Total de tokens en esas oraciones: 871
# Total de types (palabras únicas) en esas oraciones: 730
# Media de longitud de las oraciones con : 32.25925925925926
#
#
# Estadisticas para la palabra: minusválidos
# ----------------------------------------
# Número de oraciones que contienen: 64
# Total de tokens en esas oraciones: 2174
# Total de types (palabras únicas) en esas oraciones: 1790
# Media de longitud de las oraciones con : 33.96875
#
#
# Estadisticas para la palabra: minusválida
# ----------------------------------------
# Número de oraciones que contienen: 11
# Total de tokens en esas oraciones: 287
# Total de types (palabras únicas) en esas oraciones: 254
# Media de longitud de las oraciones con : 26.09090909090909
#
#
# Estadisticas para la palabra: minusválidas
# ----------------------------------------
# Número de oraciones que contienen: 5
# Total de tokens en esas oraciones: 134
# Total de types (palabras únicas) en esas oraciones: 125
# Media de longitud de las oraciones con : 26.8
# (5, 134, 125, 26.8, 25.0)

# %%
contar_oraciones_con_palabra(content2, 'inválido')
contar_oraciones_con_palabra(content2, 'inválidas')
contar_oraciones_con_palabra(content2, 'inválida')
contar_oraciones_con_palabra(content2, 'inválidos')
# Out:
# Estadisticas para la palabra: inválido
# ----------------------------------------
# Número de oraciones que contienen: 9
# Total de tokens en esas oraciones: 424
# Total de types (palabras únicas) en esas oraciones: 327
# Media de longitud de las oraciones con : 47.111111111111114
#
#
# Estadisticas para la palabra: inválidas
# ----------------------------------------
# Número de oraciones que contienen: 1
# Total de tokens en esas oraciones: 14
# Total de types (palabras únicas) en esas oraciones: 14
# Media de longitud de las oraciones con : 14.0
#
#
# Estadisticas para la palabra: inválida
# ----------------------------------------
# Número de oraciones que contienen: 3
# Total de tokens en esas oraciones: 127
# Total de types (palabras únicas) en esas oraciones: 100
# Media de longitud de las oraciones con : 42.333333333333336
#
#
# Estadisticas para la palabra: inválidos
# ----------------------------------------
# Número de oraciones que contienen: 5
# Total de tokens en esas oraciones: 173
# Total de types (palabras únicas) en esas oraciones: 138
# Media de longitud de las oraciones con : 34.6
# (5, 173, 138, 34.6, 27.6)

# %%
contar_oraciones_con_palabra(content, 'inválido')
contar_oraciones_con_palabra(content, 'inválidas')
contar_oraciones_con_palabra(content, 'inválida')
contar_oraciones_con_palabra(content, 'inválidos')
# Out:
# Estadisticas para la palabra: inválido
# ----------------------------------------
# Número de oraciones que contienen: 65
# Total de tokens en esas oraciones: 2009
# Total de types (palabras únicas) en esas oraciones: 1664
# Media de longitud de las oraciones con : 30.907692307692308
#
#
# Estadisticas para la palabra: inválidas
# ----------------------------------------
# Número de oraciones que contienen: 7
# Total de tokens en esas oraciones: 275
# Total de types (palabras únicas) en esas oraciones: 233
# Media de longitud de las oraciones con : 39.285714285714285
#
#
# Estadisticas para la palabra: inválida
# ----------------------------------------
# Número de oraciones que contienen: 27
# Total de tokens en esas oraciones: 848
# Total de types (palabras únicas) en esas oraciones: 693
# Media de longitud de las oraciones con : 31.40740740740741
#
#
# Estadisticas para la palabra: inválidos
# ----------------------------------------
# Número de oraciones que contienen: 33
# Total de tokens en esas oraciones: 857
# Total de types (palabras únicas) en esas oraciones: 747
# Media de longitud de las oraciones con : 25.96969696969697
# (33, 857, 747, 25.96969696969697, 22.636363636363637)

# %%
contar_oraciones_con_palabra(content2, 'disminuido')
contar_oraciones_con_palabra(content2, 'disminuidos')
contar_oraciones_con_palabra(content2, 'disminuida')
contar_oraciones_con_palabra(content2, 'disminuidas')
# Out:
# Estadisticas para la palabra: disminuido
# ----------------------------------------
# Número de oraciones que contienen: 16
# Total de tokens en esas oraciones: 562
# Total de types (palabras únicas) en esas oraciones: 467
# Media de longitud de las oraciones con : 35.125
#
#
# Estadisticas para la palabra: disminuidos
# ----------------------------------------
# Número de oraciones que contienen: 0
# Total de tokens en esas oraciones: 0
# Total de types (palabras únicas) en esas oraciones: 0
# Media de longitud de las oraciones con : 0
#
#
# Estadisticas para la palabra: disminuida
# ----------------------------------------
# Número de oraciones que contienen: 9
# Total de tokens en esas oraciones: 310
# Total de types (palabras únicas) en esas oraciones: 249
# Media de longitud de las oraciones con : 34.44444444444444
#
#
# Estadisticas para la palabra: disminuidas
# ----------------------------------------
# Número de oraciones que contienen: 0
# Total de tokens en esas oraciones: 0
# Total de types (palabras únicas) en esas oraciones: 0
# Media de longitud de las oraciones con : 0
# (0, 0, 0, 0, 0)

# %%
contar_oraciones_con_palabra(content, 'disminuido')
contar_oraciones_con_palabra(content, 'disminuidos')
contar_oraciones_con_palabra(content, 'disminuida')
contar_oraciones_con_palabra(content, 'disminuidas')
# Out:
# Estadisticas para la palabra: disminuido
# ----------------------------------------
# Número de oraciones que contienen: 87
# Total de tokens en esas oraciones: 2849
# Total de types (palabras únicas) en esas oraciones: 2383
# Media de longitud de las oraciones con : 32.747126436781606
#
#
# Estadisticas para la palabra: disminuidos
# ----------------------------------------
# Número de oraciones que contienen: 12
# Total de tokens en esas oraciones: 648
# Total de types (palabras únicas) en esas oraciones: 475
# Media de longitud de las oraciones con : 54.0
#
#
# Estadisticas para la palabra: disminuida
# ----------------------------------------
# Número de oraciones que contienen: 8
# Total de tokens en esas oraciones: 360
# Total de types (palabras únicas) en esas oraciones: 287
# Media de longitud de las oraciones con : 45.0
#
#
# Estadisticas para la palabra: disminuidas
# ----------------------------------------
# Número de oraciones que contienen: 4
# Total de tokens en esas oraciones: 214
# Total de types (palabras únicas) en esas oraciones: 163
# Media de longitud de las oraciones con : 53.5
# (4, 214, 163, 53.5, 40.75)

# %%
contar_oraciones_con_palabra(content2, 'retrasado')
contar_oraciones_con_palabra(content2, 'retrasados')
contar_oraciones_con_palabra(content2, 'retrasada')
contar_oraciones_con_palabra(content2, 'retrasadas')
# Out:
# Estadisticas para la palabra: retrasado
# ----------------------------------------
# Número de oraciones que contienen: 9
# Total de tokens en esas oraciones: 121
# Total de types (palabras únicas) en esas oraciones: 114
# Media de longitud de las oraciones con : 13.444444444444445
#
#
# Estadisticas para la palabra: retrasados
# ----------------------------------------
# Número de oraciones que contienen: 6
# Total de tokens en esas oraciones: 160
# Total de types (palabras únicas) en esas oraciones: 135
# Media de longitud de las oraciones con : 26.666666666666668
#
#
# Estadisticas para la palabra: retrasada
# ----------------------------------------
# Número de oraciones que contienen: 9
# Total de tokens en esas oraciones: 222
# Total de types (palabras únicas) en esas oraciones: 197
# Media de longitud de las oraciones con : 24.666666666666668
#
#
# Estadisticas para la palabra: retrasadas
# ----------------------------------------
# Número de oraciones que contienen: 0
# Total de tokens en esas oraciones: 0
# Total de types (palabras únicas) en esas oraciones: 0
# Media de longitud de las oraciones con : 0
# (0, 0, 0, 0, 0)

# %%
contar_oraciones_con_palabra(content, 'retrasado')
contar_oraciones_con_palabra(content, 'retrasados')
contar_oraciones_con_palabra(content, 'retrasada')
contar_oraciones_con_palabra(content, 'retrasadas')
# Out:
# Estadisticas para la palabra: retrasado
# ----------------------------------------
# Número de oraciones que contienen: 60
# Total de tokens en esas oraciones: 1839
# Total de types (palabras únicas) en esas oraciones: 1516
# Media de longitud de las oraciones con : 30.65
#
#
# Estadisticas para la palabra: retrasados
# ----------------------------------------
# Número de oraciones que contienen: 43
# Total de tokens en esas oraciones: 1159
# Total de types (palabras únicas) en esas oraciones: 998
# Media de longitud de las oraciones con : 26.953488372093023
#
#
# Estadisticas para la palabra: retrasada
# ----------------------------------------
# Número de oraciones que contienen: 37
# Total de tokens en esas oraciones: 975
# Total de types (palabras únicas) en esas oraciones: 829
# Media de longitud de las oraciones con : 26.35135135135135
#
#
# Estadisticas para la palabra: retrasadas
# ----------------------------------------
# Número de oraciones que contienen: 3
# Total de tokens en esas oraciones: 71
# Total de types (palabras únicas) en esas oraciones: 64
# Media de longitud de las oraciones con : 23.666666666666668
# (3, 71, 64, 23.666666666666668, 21.333333333333332)

# %%
contar_oraciones_con_palabra(content2, 'tetrapléjico')
contar_oraciones_con_palabra(content2, 'tetrapléjicos')
contar_oraciones_con_palabra(content2, 'tetrapléjica')
contar_oraciones_con_palabra(content2, 'tetrapléjicas')
# Out:
# Estadisticas para la palabra: tetrapléjico
# ----------------------------------------
# Número de oraciones que contienen: 10
# Total de tokens en esas oraciones: 283
# Total de types (palabras únicas) en esas oraciones: 244
# Media de longitud de las oraciones con : 28.3
#
#
# Estadisticas para la palabra: tetrapléjicos
# ----------------------------------------
# Número de oraciones que contienen: 1
# Total de tokens en esas oraciones: 38
# Total de types (palabras únicas) en esas oraciones: 30
# Media de longitud de las oraciones con : 38.0
#
#
# Estadisticas para la palabra: tetrapléjica
# ----------------------------------------
# Número de oraciones que contienen: 14
# Total de tokens en esas oraciones: 388
# Total de types (palabras únicas) en esas oraciones: 344
# Media de longitud de las oraciones con : 27.714285714285715
#
#
# Estadisticas para la palabra: tetrapléjicas
# ----------------------------------------
# Número de oraciones que contienen: 0
# Total de tokens en esas oraciones: 0
# Total de types (palabras únicas) en esas oraciones: 0
# Media de longitud de las oraciones con : 0
# (0, 0, 0, 0, 0)

# %%
contar_oraciones_con_palabra(content, 'tetrapléjico')
contar_oraciones_con_palabra(content, 'tetrapléjicos')
contar_oraciones_con_palabra(content, 'tetrapléjica')
contar_oraciones_con_palabra(content, 'tetrapléjicas')
# Out:
# Estadisticas para la palabra: tetrapléjico
# ----------------------------------------
# Número de oraciones que contienen: 47
# Total de tokens en esas oraciones: 1401
# Total de types (palabras únicas) en esas oraciones: 1206
# Media de longitud de las oraciones con : 29.80851063829787
#
#
# Estadisticas para la palabra: tetrapléjicos
# ----------------------------------------
# Número de oraciones que contienen: 16
# Total de tokens en esas oraciones: 463
# Total de types (palabras únicas) en esas oraciones: 403
# Media de longitud de las oraciones con : 28.9375
#
#
# Estadisticas para la palabra: tetrapléjica
# ----------------------------------------
# Número de oraciones que contienen: 81
# Total de tokens en esas oraciones: 2228
# Total de types (palabras únicas) en esas oraciones: 1955
# Media de longitud de las oraciones con : 27.506172839506174
#
#
# Estadisticas para la palabra: tetrapléjicas
# ----------------------------------------
# Número de oraciones que contienen: 0
# Total de tokens en esas oraciones: 0
# Total de types (palabras únicas) en esas oraciones: 0
# Media de longitud de las oraciones con : 0
# (0, 0, 0, 0, 0)

# %%
def contar_oraciones_con_expresion(texto_input, expresion):
    oraciones = sent_tokenize(texto_input)

    count = 0
    total_tokens = 0
    total_types = 0
    longitud_oraciones = []

    patron = re.compile(expresion)

    for oracion in oraciones:
        if patron.search(oracion):
            palabras = word_tokenize(oracion)
            count += 1
            num_tokens = len(palabras)
            num_types = len(set(palabras))
            total_tokens += num_tokens
            total_types += num_types
            longitud_oraciones.append(num_tokens)


    if count > 0:
        media_longitud = total_tokens / count
        media_types = total_types / count
    else:
        media_longitud = 0
        media_types = 0

    print(f"Número de oraciones que contienen la expresión '{expresion}': {count}")
    print(f"Total de tokens en esas oraciones: {total_tokens}")
    print(f"Total de types (palabras únicas) en esas oraciones: {total_types}")
    print(f"Media de longitud de las oraciones con la expresión: {media_longitud}")

    return count, total_tokens, total_types, media_longitud, media_types

# %%
contar_oraciones_con_expresion(content, "padece discapacidad")
# Out:
# Número de oraciones que contienen la expresión 'padece discapacidad': 54
# Total de tokens en esas oraciones: 1612
# Total de types (palabras únicas) en esas oraciones: 1374
# Media de longitud de las oraciones con la expresión: 29.85185185185185
# Media de types (palabras únicas) por oración: 25.444444444444443
# (54, 1612, 1374, 29.85185185185185, 25.444444444444443)

# %%
contar_oraciones_con_expresion(content, "padecen discapacidad")
# Out:
# Número de oraciones que contienen la expresión 'padecen discapacidad': 76
# Total de tokens en esas oraciones: 2236
# Total de types (palabras únicas) en esas oraciones: 1913
# Media de longitud de las oraciones con la expresión: 29.42105263157895
# Media de types (palabras únicas) por oración: 25.17105263157895
# (76, 2236, 1913, 29.42105263157895, 25.17105263157895)

# %%
contar_oraciones_con_expresion(content, "sufren discapacidad")
# Out:
# Número de oraciones que contienen la expresión 'sufren discapacidad': 93
# Total de tokens en esas oraciones: 2743
# Total de types (palabras únicas) en esas oraciones: 2384
# Media de longitud de las oraciones con la expresión: 29.49462365591398
# Media de types (palabras únicas) por oración: 25.634408602150536
# (93, 2743, 2384, 29.49462365591398, 25.634408602150536)

# %%
contar_oraciones_con_expresion(content, "sufre discapacidad")
# Out:
# Número de oraciones que contienen la expresión 'sufre discapacidad': 57
# Total de tokens en esas oraciones: 1486
# Total de types (palabras únicas) en esas oraciones: 1298
# Media de longitud de las oraciones con la expresión: 26.07017543859649
# Media de types (palabras únicas) por oración: 22.771929824561404
# (57, 1486, 1298, 26.07017543859649, 22.771929824561404)

# %%
contar_oraciones_con_expresion(content, "hombres de negocios")
# Out:
# Número de oraciones que contienen la expresión 'hombres de negocios': 103
# Total de tokens en esas oraciones: 3644
# Total de types (palabras únicas) en esas oraciones: 2995
# Media de longitud de las oraciones con la expresión: 35.37864077669903
# Media de types (palabras únicas) por oración: 29.07766990291262
# (103, 3644, 2995, 35.37864077669903, 29.07766990291262)

# %%
contar_oraciones_con_expresion(content2, "padece discapacidad")
# Out:
# Número de oraciones que contienen la expresión 'padece discapacidad': 11
# Total de tokens en esas oraciones: 343
# Total de types (palabras únicas) en esas oraciones: 290
# Media de longitud de las oraciones con la expresión: 31.181818181818183
# Media de types (palabras únicas) por oración: 26.363636363636363
# (11, 343, 290, 31.181818181818183, 26.363636363636363)

# %%
contar_oraciones_con_expresion(content2, "padecen discapacidad")
# Out:
# Número de oraciones que contienen la expresión 'padecen discapacidad': 31
# Total de tokens en esas oraciones: 890
# Total de types (palabras únicas) en esas oraciones: 768
# Media de longitud de las oraciones con la expresión: 28.70967741935484
# Media de types (palabras únicas) por oración: 24.774193548387096
# (31, 890, 768, 28.70967741935484, 24.774193548387096)

# %%
contar_oraciones_con_expresion(content2, "sufren discapacidad")
# Out:
# Número de oraciones que contienen la expresión 'sufren discapacidad': 7
# Total de tokens en esas oraciones: 200
# Total de types (palabras únicas) en esas oraciones: 176
# Media de longitud de las oraciones con la expresión: 28.571428571428573
# Media de types (palabras únicas) por oración: 25.142857142857142
# (7, 200, 176, 28.571428571428573, 25.142857142857142)

# %%
contar_oraciones_con_expresion(content2, "sufre discapacidad")
# Out:
# Número de oraciones que contienen la expresión 'sufre discapacidad': 18
# Total de tokens en esas oraciones: 483
# Total de types (palabras únicas) en esas oraciones: 434
# Media de longitud de las oraciones con la expresión: 26.833333333333332
# Media de types (palabras únicas) por oración: 24.11111111111111
# (18, 483, 434, 26.833333333333332, 24.11111111111111)

# %%
contar_oraciones_con_expresion(content2, "hombres de negocios")
# Out:
# Número de oraciones que contienen la expresión 'hombres de negocios': 19
# Total de tokens en esas oraciones: 767
# Total de types (palabras únicas) en esas oraciones: 621
# Media de longitud de las oraciones con la expresión: 40.36842105263158
# Media de types (palabras únicas) por oración: 32.68421052631579
# (19, 767, 621, 40.36842105263158, 32.68421052631579)

# %%
def calcular_estadisticas_texto_nltk(texto_input):
    oraciones = sent_tokenize(texto_input)

    total_oraciones = len(oraciones)
    total_tokens = 0
    total_types = set()
    longitud_oraciones = []

    for oracion in oraciones:
        palabras = word_tokenize(oracion)
        num_tokens = len(palabras)
        total_tokens += num_tokens
        total_types.update(palabras)
        longitud_oraciones.append(num_tokens)

    if total_oraciones > 0:
        media_longitud = total_tokens / total_oraciones
    else:
        media_longitud = 0

    num_types_total = len(total_types)

    print(f"Número total de oraciones: {total_oraciones}")
    print(f"Número total de tokens: {total_tokens}")
    print(f"Número total de types (palabras únicas): {num_types_total}")
    print(f"Media de longitud de las oraciones (tokens): {media_longitud}")

    return total_oraciones, total_tokens, num_types_total, media_longitud

# %%
calcular_estadisticas_texto_nltk(content)
# Out:
# Número total de oraciones: 2734
# Número total de tokens: 75992
# Número total de types (palabras únicas): 14006
# Media de longitud de las oraciones (tokens): 27.795171909290417
# (2734, 75992, 14006, 27.795171909290417)

# %%
calcular_estadisticas_texto_nltk(content2)
# Out:
# Número total de oraciones: 491
# Número total de tokens: 13404
# Número total de types (palabras únicas): 4075
# Media de longitud de las oraciones (tokens): 27.29938900203666
# (491, 13404, 4075, 27.29938900203666)
